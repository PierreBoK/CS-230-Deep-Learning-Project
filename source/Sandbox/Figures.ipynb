# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir(r"C:\Users\gotta\OneDrive\Documents\Bureau\X\4A\US\Stanford\Classes\CS 230\Project\CS-230-Deep-Learning-Project")

# %%
CAISO_lmp=pd.read_csv(r"data\CAISO_LMP_Forecasts\CAISO_LMP_Forecast_2023_03\CAISO_LMP_Forecast_2023_03_processed.csv")
CAISO_lmp
# Out:
#      Year  Month  Day  Hour        LMP
# 0    2023      2   28    24  82.709673
# 1    2023      3    1     1  92.794403
# 2    2023      3    1     2  88.614607
# 3    2023      3    1     3  88.095237
# 4    2023      3    1     4  88.533493
# ..    ...    ...  ...   ...        ...
# 715  2023      3   30    20  95.193883
# 716  2023      3   30    21  94.628370
# 717  2023      3   30    22  87.972780
# 718  2023      3   30    23  77.162780
# 719  2023      3   30    24  70.070410
#
# [720 rows x 5 columns]

# %%
#Picking the 15 Mar. 2023 as example day

CAISO_lmp_day = CAISO_lmp[
    (CAISO_lmp['Year'] == 2023) &
    (CAISO_lmp['Month'] == 3) &
    (CAISO_lmp['Day'] == 15)
]
CAISO_lmp_day
# Out:
#      Year  Month  Day  Hour         LMP
# 336  2023      3   15     1   64.752353
# 337  2023      3   15     2   61.330200
# 338  2023      3   15     3   60.982147
# 339  2023      3   15     4   61.270310
# 340  2023      3   15     5   63.870373
# 341  2023      3   15     6   68.264460
# 342  2023      3   15     7   93.447693
# 343  2023      3   15     8  108.811247
# 344  2023      3   15     9   91.149740
# 345  2023      3   15    10   69.912953
# 346  2023      3   15    11   63.815027
# 347  2023      3   15    12   56.959170
# 348  2023      3   15    13   49.307070
# 349  2023      3   15    14   46.488060
# 350  2023      3   15    15   42.047887
# 351  2023      3   15    16   42.487327
# 352  2023      3   15    17   52.750073
# 353  2023      3   15    18   63.679433
# 354  2023      3   15    19   89.924323
# 355  2023      3   15    20  109.925463
# 356  2023      3   15    21   95.119453
# 357  2023      3   15    22   90.258057
# ...

# %%
#Pick the 15 Marr.2023 for renewables and load
CAIS_ren=pd.read_csv(r"data\CAISO_REN_DAM_Forecasts\CAISO_DAM_Forecast_2023_03\CAISO_DAM_REN_Forecast_2023_03_processed.csv")
CAIS_ren_day = CAIS_ren[
    (CAIS_ren['Year'] == 2023) &
    (CAIS_ren['Month'] == 3) &
    (CAIS_ren['Day'] == 15)
]
CAIS_ren_day
# Out:
#      Year  Month  Day  OPR_HR RENEWABLE_TYPE       MW
# 672  2023      3   15       1          Solar     0.00
# 673  2023      3   15       1           Wind  2137.29
# 674  2023      3   15       2          Solar     0.00
# 675  2023      3   15       2           Wind  2014.88
# 676  2023      3   15       3          Solar     0.00
# 677  2023      3   15       3           Wind  1871.75
# 678  2023      3   15       4          Solar     0.00
# 679  2023      3   15       4           Wind  1799.18
# 680  2023      3   15       5          Solar     0.00
# 681  2023      3   15       5           Wind  1691.09
# 682  2023      3   15       6          Solar     0.00
# 683  2023      3   15       6           Wind  1467.51
# 684  2023      3   15       7          Solar     0.55
# 685  2023      3   15       7           Wind  1418.37
# 686  2023      3   15       8          Solar   456.35
# 687  2023      3   15       8           Wind  1338.90
# ...

# %%
CAISO_load=pd.read_csv(r"data\CAISO_DAM_Load_Forecasts\CAISO_DAM_Load_Forecast_2023_03\CAISO_DAM_Load_Forecast_2023_03_processed.csv")
CAISO_load_day = CAISO_load[
    (CAISO_load['Year'] == 2023) &
    (CAISO_load['Month'] == 3) &
    (CAISO_load['Day'] == 15)
] 
CAISO_load_day
# Out:
#      Year  Month  Day  Hour        MW
# 336  2023      3   15     1  22098.12
# 337  2023      3   15     2  21323.14
# 338  2023      3   15     3  20807.96
# 339  2023      3   15     4  20661.09
# 340  2023      3   15     5  21046.41
# 341  2023      3   15     6  22226.38
# 342  2023      3   15     7  24472.32
# 343  2023      3   15     8  26106.75
# 344  2023      3   15     9  25805.19
# 345  2023      3   15    10  24956.73
# 346  2023      3   15    11  23974.71
# 347  2023      3   15    12  23192.70
# 348  2023      3   15    13  22557.41
# 349  2023      3   15    14  21888.99
# 350  2023      3   15    15  21486.05
# 351  2023      3   15    16  21516.13
# 352  2023      3   15    17  22124.06
# 353  2023      3   15    18  23574.70
# 354  2023      3   15    19  25542.43
# 355  2023      3   15    20  27280.58
# 356  2023      3   15    21  27044.83
# 357  2023      3   15    22  26198.47
# 358  2023      3   15    23  24651.50
# 359  2023      3   15    24  23145.03

# %%
# Plotting the data
fig, ax1 = plt.subplots(figsize=(15, 10))

# Plot LMP on the primary Y-axis (left)
ax1.plot(CAISO_lmp_day['Hour'], CAISO_lmp_day['LMP'], label='LMP', color='black', marker='o')
ax1.set_xlabel('Hour of the Day')
ax1.set_ylabel('LMP ($/MWh)', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.grid()

# Create a second Y-axis for Load (right)
ax2 = ax1.twinx()

# Plot Load on the secondary Y-axis
ax2.plot(CAISO_load_day['Hour'], CAISO_load_day['MW'], label='Load', color='red', marker='o')
ax2.set_ylabel('Load (MW)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add stacked bar plots for Solar and Wind generation on the secondary Y-axis
ax2.bar(solar_generation['OPR_HR'], solar_generation['MW'], label='Solar Generation', color='orange', alpha=0.7)
ax2.bar(wind_generation['OPR_HR'], wind_generation['MW'], label='Wind Generation', color='lightblue', alpha=0.7, 
        bottom=solar_generation['MW'].values)

# Add a title and legends
fig.suptitle('CAISO LMP, Stacked Solar and Wind Generation, and Load on March 15, 2023', fontsize=16)
# Combine legends from both axes
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
fig.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper left', bbox_to_anchor=(0.15, 0.85))

plt.show()
